# %% [markdown]
# <a href="https://colab.research.google.com/github/guru3/deep-learning-with-python-using-keras/blob/master/GANs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. the generator
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x) #we prefer leakyReLu over ReLu
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Using TensorFlow backend.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2. discriminator

discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick! - for randomness
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
# !mkdir gan_images

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = './gan_images/'

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# discriminator loss at step 0: 5.928256
# adversarial loss at step 0: 15.506805
# discriminator loss at step 100: 0.59736043
# adversarial loss at step 100: 1.6947272
# discriminator loss at step 200: 0.6897151
# adversarial loss at step 200: 0.7697958
# discriminator loss at step 300: 0.7120018
# adversarial loss at step 300: 0.7693885
# discriminator loss at step 400: 0.6842994
# adversarial loss at step 400: 0.8004087
# discriminator loss at step 500: 0.6971377
# adversarial loss at step 500: 0.89055127
# discriminator loss at step 600: 0.7029184
# adversarial loss at step 600: 0.73942614
# discriminator loss at step 700: 0.80652666
# adversarial loss at step 700: 0.87284863
# discriminator loss at step 800: 0.69621456
# adversarial loss at step 800: 0.7419697
# discriminator loss at step 900: 0.7672323
# adversarial loss at step 900: 0.75263304
# discriminator loss at step 1000: 0.70288515
# adversarial loss at step 1000: 0.74958885
# discriminator loss at step 1100: 0.69487256
# adversarial loss at step 1100: 0.74827135
# discriminator loss at step 1200: 0.6934267
# adversarial loss at step 1200: 0.7424193
# discriminator loss at step 1300: 0.69304776
# adversarial loss at step 1300: 0.7239316
# discriminator loss at step 1400: 0.7034191
# adversarial loss at step 1400: 0.75015837
# discriminator loss at step 1500: 0.6853354
# adversarial loss at step 1500: 0.73993826
# discriminator loss at step 1600: 0.71880466
# adversarial loss at step 1600: 0.7127353
# discriminator loss at step 1700: 0.6942173
# adversarial loss at step 1700: 0.7035047
# discriminator loss at step 1800: 0.6966926
# adversarial loss at step 1800: 0.9090498
# discriminator loss at step 1900: 0.6894965
# adversarial loss at step 1900: 1.8267742
# discriminator loss at step 2000: 0.69297695
# adversarial loss at step 2000: 0.7263581
# discriminator loss at step 2100: 0.7020342
# adversarial loss at step 2100: 0.7301582
# discriminator loss at step 2200: 0.69079083
# adversarial loss at step 2200: 0.74455035
# discriminator loss at step 2300: 0.7052457
# adversarial loss at step 2300: 0.7322813
# discriminator loss at step 2400: 0.69058746
# adversarial loss at step 2400: 0.72904384
# discriminator loss at step 2500: 0.6924942
# adversarial loss at step 2500: 0.73623973
# discriminator loss at step 2600: 0.6979007
# adversarial loss at step 2600: 0.7449554
# discriminator loss at step 2700: 0.66738015
# adversarial loss at step 2700: 1.0167574
# discriminator loss at step 2800: 0.69957626
# adversarial loss at step 2800: 0.75031894
# discriminator loss at step 2900: 0.6924947
# adversarial loss at step 2900: 0.7615043
# discriminator loss at step 3000: 0.7295495
# adversarial loss at step 3000: 0.736345
# discriminator loss at step 3100: 0.6987742
# adversarial loss at step 3100: 0.7549389
# discriminator loss at step 3200: 0.7066538
# adversarial loss at step 3200: 0.7442695
# discriminator loss at step 3300: 0.7032925
# adversarial loss at step 3300: 0.7747651
# discriminator loss at step 3400: 0.7024081
# adversarial loss at step 3400: 0.72597843
# discriminator loss at step 3500: 0.70060575
# adversarial loss at step 3500: 0.7162806
# discriminator loss at step 3600: 0.6777984
# adversarial loss at step 3600: 0.8065689
# discriminator loss at step 3700: 0.69221294
# adversarial loss at step 3700: 0.757393
# discriminator loss at step 3800: 0.7353411
# adversarial loss at step 3800: 0.7963773
# discriminator loss at step 3900: 0.68497217
# adversarial loss at step 3900: 0.7353061
# discriminator loss at step 4000: 0.7031538
# adversarial loss at step 4000: 0.7753011
# discriminator loss at step 4100: 0.6946303
# adversarial loss at step 4100: 0.746354
# discriminator loss at step 4200: 0.6938768
# adversarial loss at step 4200: 0.7419842
# discriminator loss at step 4300: 0.709047
# adversarial loss at step 4300: 0.8396231
# discriminator loss at step 4400: 0.71097076
# adversarial loss at step 4400: 0.7352017
# discriminator loss at step 4500: 0.6954409
# adversarial loss at step 4500: 0.7708379
# discriminator loss at step 4600: 0.6895212
# adversarial loss at step 4600: 0.7071538
# discriminator loss at step 4700: 0.68907195
# adversarial loss at step 4700: 0.78917104
# discriminator loss at step 4800: 0.6855024
# adversarial loss at step 4800: 0.7740592
# discriminator loss at step 4900: 0.70396453
# adversarial loss at step 4900: 0.74494314
# discriminator loss at step 5000: 0.6745091
# adversarial loss at step 5000: 0.69157904
# discriminator loss at step 5100: 0.71753365
# adversarial loss at step 5100: 0.8864066
# discriminator loss at step 5200: 0.69553083
# adversarial loss at step 5200: 0.7196826
# discriminator loss at step 5300: 0.808269
# adversarial loss at step 5300: 1.0087404
# discriminator loss at step 5400: 0.6530965
# adversarial loss at step 5400: 0.81819
# discriminator loss at step 5500: 0.68799794
# adversarial loss at step 5500: 0.93022573
# discriminator loss at step 5600: 0.72799855
# adversarial loss at step 5600: 0.84254056
# discriminator loss at step 5700: 0.6973839
# adversarial loss at step 5700: 0.7990924
# discriminator loss at step 5800: 0.70520896
# adversarial loss at step 5800: 0.73718107
# discriminator loss at step 5900: 0.668949
# adversarial loss at step 5900: 0.60035217
# discriminator loss at step 6000: 0.6670469
# adversarial loss at step 6000: 0.8190756
# discriminator loss at step 6100: 0.72332555
# adversarial loss at step 6100: 0.77061653
# discriminator loss at step 6200: 0.69664466
# adversarial loss at step 6200: 0.7849598
# discriminator loss at step 6300: 0.7042226
# adversarial loss at step 6300: 0.7820831
# discriminator loss at step 6400: 0.7486294
# adversarial loss at step 6400: 0.68707234
# discriminator loss at step 6500: 0.67151994
# adversarial loss at step 6500: 0.79864013
# discriminator loss at step 6600: 0.7084036
# adversarial loss at step 6600: 0.7665888
# discriminator loss at step 6700: 0.6768807
# adversarial loss at step 6700: 0.8411118
# discriminator loss at step 6800: 0.6341102
# adversarial loss at step 6800: 0.700928
# discriminator loss at step 6900: 0.6999611
# adversarial loss at step 6900: 0.81337273
# discriminator loss at step 7000: 0.7098711
# adversarial loss at step 7000: 0.9309071
# discriminator loss at step 7100: 0.68174285
# adversarial loss at step 7100: 0.781311
# discriminator loss at step 7200: 0.72563326
# adversarial loss at step 7200: 0.8059842
# discriminator loss at step 7300: 0.69811475
# adversarial loss at step 7300: 0.8108614
# discriminator loss at step 7400: 0.69722426
# adversarial loss at step 7400: 0.82356346
# discriminator loss at step 7500: 0.69046897
# adversarial loss at step 7500: 0.7794398
# discriminator loss at step 7600: 0.6654647
# adversarial loss at step 7600: 1.0025413
# discriminator loss at step 7700: 0.68179727
# adversarial loss at step 7700: 0.87081087
# discriminator loss at step 7800: 0.6729113
# adversarial loss at step 7800: 0.81349313
# discriminator loss at step 7900: 0.6223801
# adversarial loss at step 7900: 0.9820205
# discriminator loss at step 8000: 0.718674
# adversarial loss at step 8000: 0.927653
# discriminator loss at step 8100: 0.6630465
# adversarial loss at step 8100: 0.81958044
# discriminator loss at step 8200: 0.7287709
# adversarial loss at step 8200: 0.7542669
# discriminator loss at step 8300: 0.65176415
# adversarial loss at step 8300: 1.1067898
# discriminator loss at step 8400: 0.68925655
# adversarial loss at step 8400: 0.7717032
# discriminator loss at step 8500: 0.6705016
# adversarial loss at step 8500: 0.75167435
# discriminator loss at step 8600: 0.71334255
# adversarial loss at step 8600: 0.68229955
# discriminator loss at step 8700: 0.7146249
# adversarial loss at step 8700: 0.8199979
# discriminator loss at step 8800: 0.6749309
# adversarial loss at step 8800: 0.87186354
# discriminator loss at step 8900: 0.6599399
# adversarial loss at step 8900: 0.832384
# discriminator loss at step 9000: 0.6687789
# adversarial loss at step 9000: 0.8244573
# discriminator loss at step 9100: 0.666554
# adversarial loss at step 9100: 0.67022914
# discriminator loss at step 9200: 0.6894434
# adversarial loss at step 9200: 0.9552801
# discriminator loss at step 9300: 0.66264397
# adversarial loss at step 9300: 0.776868
# discriminator loss at step 9400: 0.6440004
# adversarial loss at step 9400: 0.80822897
# discriminator loss at step 9500: 0.65464604
# adversarial loss at step 9500: 0.83132184
# discriminator loss at step 9600: 0.66064036
# adversarial loss at step 9600: 0.7994455
# discriminator loss at step 9700: 0.67627543
# adversarial loss at step 9700: 0.8276494
# discriminator loss at step 9800: 0.66703117
# adversarial loss at step 9800: 0.77461433
# discriminator loss at step 9900: 0.6849082
# adversarial loss at step 9900: 0.842995

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
